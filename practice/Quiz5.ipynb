# %%
# Quiz 5) 당신은 cocoa 서비스를 이용하는 택시 기사입니다
# 50명의 승객과 매칭 기회가 있을 때, 총 탑승 수를 구하는 프로그램을 작성하시오

# 조건1: 승객별 운행 소요 시간은 5~ 50분 사이의 난수로 정해집니다
# 조건2: 당신은 소요시간 5~15분 사이의 승객만 매칭 해야 합니다

# %%
from random import *

customer = range(1,51) # 승객
customer_taxi = 0 # 총 탑승객 수

for cst in customer :
    cst_time = randint(5,50)
    if cst_time >= 5 and cst_time <= 15:
        customer_taxi += 1
        print("[O] {0}번째 손님(소요시간: {1}분)".format(cst,cst_time))
    
    else:
        print("[ ] {0}번째 손님(소요시간: {1}분)".format(cst,cst_time))

print("총 탑승객 : {0} 분".format(customer_taxi))
# Out:
# [ ] 1번째 손님(소요시간: 21분)
# [O] 2번째 손님(소요시간: 6분)
# [ ] 3번째 손님(소요시간: 44분)
# [ ] 4번째 손님(소요시간: 17분)
# [O] 5번째 손님(소요시간: 10분)
# [O] 6번째 손님(소요시간: 12분)
# [ ] 7번째 손님(소요시간: 37분)
# [ ] 8번째 손님(소요시간: 38분)
# [ ] 9번째 손님(소요시간: 43분)
# [ ] 10번째 손님(소요시간: 30분)
# [O] 11번째 손님(소요시간: 9분)
# [ ] 12번째 손님(소요시간: 29분)
# [ ] 13번째 손님(소요시간: 27분)
# [ ] 14번째 손님(소요시간: 41분)
# [ ] 15번째 손님(소요시간: 41분)
# [O] 16번째 손님(소요시간: 12분)
# [ ] 17번째 손님(소요시간: 31분)
# [ ] 18번째 손님(소요시간: 41분)
# [ ] 19번째 손님(소요시간: 47분)
# [ ] 20번째 손님(소요시간: 28분)
# [ ] 21번째 손님(소요시간: 49분)
# [O] 22번째 손님(소요시간: 10분)
# [O] 23번째 손님(소요시간: 12분)
# [ ] 24번째 손님(소요시간: 42분)
# [O] 25번째 손님(소요시간: 15분)
# [ ] 26번째 손님(소요시간: 40분)
# [O] 27번째 손님(소요시간: 9분)
# [O] 28번째 손님(소요시간: 7분)
# [ ] 29번째 손님(소요시간: 37분)
# [ ] 30번째 손님(소요시간: 18분)
# [ ] 31번째 손님(소요시간: 43분)
# [ ] 32번째 손님(소요시간: 24분)
# [ ] 33번째 손님(소요시간: 41분)
# [ ] 34번째 손님(소요시간: 33분)
# [O] 35번째 손님(소요시간: 15분)
# [ ] 36번째 손님(소요시간: 23분)
# [ ] 37번째 손님(소요시간: 46분)
# [O] 38번째 손님(소요시간: 9분)
# [ ] 39번째 손님(소요시간: 37분)
# [ ] 40번째 손님(소요시간: 33분)
# ...
